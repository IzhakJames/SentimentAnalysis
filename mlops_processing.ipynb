# %%
import numpy as np
import pandas as pd
import csv
from sklearn.model_selection import train_test_split

# %%
dataset_path = "all_reviews_fulldataset.csv" # use your own path
data_df = pd.read_csv(dataset_path)
data_df.head()
# Out:
#   Airline  Review ID Date Published  Overall Rating Passenger Country  \
# 0   scoot     891669      26/3/2024             3.0         Australia
# 1   scoot     891535      24/3/2024             1.0          Malaysia
# 2   scoot     891527      24/3/2024             9.0         Singapore
# 3   scoot     891411      22/3/2024             7.0     United States
# 4   scoot     891340      21/3/2024             4.0         Australia
#
#    Trip Verified                              Review Title  \
# 0   Not Verified             "not recommend flying Scoot"
# 1  Trip Verified               "whole cabin is like sauna"
# 2  Trip Verified      "professional, helpful and friendly"
# 3  Trip Verified  "seat pitch is generous and comfortable"
# 4  Trip Verified         "Very rude male flight attendant"
#
#                                               Review    Aircraft  \
# 0  My flight to Singapore was uneventful as usual...  Boeing 787
# 1  Using super old plane. Aircon was blowing warm...         NaN
# 2  I travelled with my sister, my elderly parent ...         NaN
# 3  Was assigned last two row at seat 39F with the...    A321 NEO
# 4  Very rude male flight attendant. Accessed the ...        A321
#
#   Type Of Traveller  ... Layover Date Flown Seat Comfort Cabin Staff Service  \
# 0      Solo Leisure  ...     NaN     Feb-24          1.0                 3.0
# 1      Solo Leisure  ...     NaN     Mar-24          1.0                 3.0
# 2    Family Leisure  ...     NaN     Mar-24          4.0                 5.0
# 3      Solo Leisure  ...     NaN     Mar-24          5.0                 3.0
# 4    Family Leisure  ...     NaN     Mar-24          3.0                 1.0
#
#   Food & Beverages  Ground Service  Wifi & Connectivity  Value For Money  \
# 0              1.0             3.0                  2.0              3.0
# 1              2.0             3.0                  NaN              2.0
# 2              4.0             5.0                  NaN              5.0
# 3              NaN             2.0                  2.0              5.0
# 4              NaN             4.0                  NaN              4.0
#
#    Recommended  Inflight Entertainment
# 0           no                     NaN
# 1           no                     1.0
# 2          yes                     NaN
# 3          yes                     NaN
# 4           no                     NaN
#
# [5 rows x 23 columns]

# %%
filtered_data_df = data_df[['Review', 'Recommended']].copy()
filtered_data_df
# Out:
#                                                  Review Recommended
# 0     My flight to Singapore was uneventful as usual...          no
# 1     Using super old plane. Aircon was blowing warm...          no
# 2     I travelled with my sister, my elderly parent ...         yes
# 3     Was assigned last two row at seat 39F with the...         yes
# 4     Very rude male flight attendant. Accessed the ...          no
# ...                                                 ...         ...
# 4112  SYD-OOL. Arrived at the airport on time. Fligh...          no
# 4113  Cairns-Sydney-Phuket in Business class. Was no...          no
# 4114  Had the misfortune of flying Business class fr...          no
# 4115  I have just flown from Melbourne to Sydney and...          no
# 4116  I have flown Jetstar for a while now and to be...         yes
#
# [4117 rows x 2 columns]

# %%
def clean_text(text):
    """
    Inner function for cleaning individual text entries.
    """
    replace_char=''
    return ''.join(char if char.isascii() else replace_char for char in text)

# %%
filtered_data_df['Cleaned_Review'] = filtered_data_df['Review'].apply(clean_text)

# %%
filtered_data_df.head(100)
# Out:
#                                                Review Recommended  \
# 0   My flight to Singapore was uneventful as usual...          no
# 1   Using super old plane. Aircon was blowing warm...          no
# 2   I travelled with my sister, my elderly parent ...         yes
# 3   Was assigned last two row at seat 39F with the...         yes
# 4   Very rude male flight attendant. Accessed the ...          no
# ..                                                ...         ...
# 95  I asked the counter staff to assign windows se...          no
# 96  They overcharged me for my luggage even though...          no
# 97  Clark to Heathrow via Singapore. I just had th...          no
# 98  1 hour 20 mins stood up in line to to check in...          no
# 99  My class of service is scootplus. I booked a r...          no
#
#                                        Cleaned_Review
# 0   My flight to Singapore was uneventful as usual...
# 1   Using super old plane. Aircon was blowing warm...
# 2   I travelled with my sister, my elderly parent ...
# 3   Was assigned last two row at seat 39F with the...
# 4   Very rude male flight attendant. Accessed the ...
# ..                                                ...
# 95  I asked the counter staff to assign windows se...
# 96  They overcharged me for my luggage even though...
# 97  Clark to Heathrow via Singapore. I just had th...
# 98  1 hour 20 mins stood up in line to to check in...
# 99  My class of service is scootplus. I booked a r...
#
# [100 rows x 3 columns]

# %%
distinct_values = filtered_data_df['Recommended'].unique()
distinct_values
# Out:
# array(['no', 'yes'], dtype=object)

# %%
filtered_data_df['is_negative_sentiment'] = filtered_data_df['Recommended'].map({'yes': 0, 'no': 1})
filtered_data_df
# Out:
#                                                  Review Recommended  \
# 0     My flight to Singapore was uneventful as usual...          no
# 1     Using super old plane. Aircon was blowing warm...          no
# 2     I travelled with my sister, my elderly parent ...         yes
# 3     Was assigned last two row at seat 39F with the...         yes
# 4     Very rude male flight attendant. Accessed the ...          no
# ...                                                 ...         ...
# 4112  SYD-OOL. Arrived at the airport on time. Fligh...          no
# 4113  Cairns-Sydney-Phuket in Business class. Was no...          no
# 4114  Had the misfortune of flying Business class fr...          no
# 4115  I have just flown from Melbourne to Sydney and...          no
# 4116  I have flown Jetstar for a while now and to be...         yes
#
#                                          Cleaned_Review  is_negative_sentiment
# 0     My flight to Singapore was uneventful as usual...                      1
# 1     Using super old plane. Aircon was blowing warm...                      1
# 2     I travelled with my sister, my elderly parent ...                      0
# 3     Was assigned last two row at seat 39F with the...                      0
# 4     Very rude male flight attendant. Accessed the ...                      1
# ...                                                 ...                    ...
# 4112  SYD-OOL. Arrived at the airport on time. Fligh...                      1
# 4113  Cairns-Sydney-Phuket in Business class. Was no...                      1
# 4114  Had the misfortune of flying Business class fr...                      1
# 4115  I have just flown from Melbourne to Sydney and...                      1
# 4116  I have flown Jetstar for a while now and to be...                      0
#
# [4117 rows x 4 columns]

# %%
train_test_df = filtered_data_df[['Cleaned_Review', 'is_negative_sentiment']].copy()
train_test_df
# Out:
#                                          Cleaned_Review  is_negative_sentiment
# 0     My flight to Singapore was uneventful as usual...                      1
# 1     Using super old plane. Aircon was blowing warm...                      1
# 2     I travelled with my sister, my elderly parent ...                      0
# 3     Was assigned last two row at seat 39F with the...                      0
# 4     Very rude male flight attendant. Accessed the ...                      1
# ...                                                 ...                    ...
# 4112  SYD-OOL. Arrived at the airport on time. Fligh...                      1
# 4113  Cairns-Sydney-Phuket in Business class. Was no...                      1
# 4114  Had the misfortune of flying Business class fr...                      1
# 4115  I have just flown from Melbourne to Sydney and...                      1
# 4116  I have flown Jetstar for a while now and to be...                      0
#
# [4117 rows x 2 columns]

# %%
# Define the test size (e.g., 20% for testing)
test_size = 0.2

# Split the data into features (X) and target (y) if applicable
X = train_test_df  # Adjust if you have separate feature and target columns

# Perform train-test split
X_train, X_test = train_test_split(X, test_size=test_size, random_state=42)  # Set random_state for reproducibility

# %%
# Save the train data to train.csv
X_train.to_csv('train.csv', index=False)

# Save the test data to test.csv
X_test.to_csv('test.csv', index=False)
