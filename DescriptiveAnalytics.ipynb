# %%
import pandas as pd
import numpy as np

# %%
df_scoot = pd.read_csv('scoot_reviews.csv')
df_scoot.head()
# Out:
#   Date Published  Overall Rating Passenger Country  Trip Verified  \
# 0     2024-03-26             3.0         Australia   Not Verified
# 1     2024-03-24             1.0          Malaysia  Trip Verified
# 2     2024-03-24             9.0         Singapore  Trip Verified
# 3     2024-03-22             7.0     United States  Trip Verified
# 4     2024-03-21             4.0         Australia  Trip Verified
#
#                                Review Title  \
# 0             "not recommend flying Scoot"
# 1               "whole cabin is like sauna"
# 2      "professional, helpful and friendly"
# 3  "seat pitch is generous and comfortable"
# 4         "Very rude male flight attendant"
#
#                                               Review    Aircraft  \
# 0  My flight to Singapore was uneventful as usual...  Boeing 787
# 1  Using super old plane. Aircon was blowing warm...         NaN
# 2  I travelled with my sister, my elderly parent ...         NaN
# ...

# %%
df_scoot.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 683 entries, 0 to 682
# Data columns (total 21 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Date Published          683 non-null    object
#  1   Overall Rating          662 non-null    float64
#  2   Passenger Country       683 non-null    object
#  3   Trip Verified           437 non-null    object
#  4   Review Title            683 non-null    object
#  5   Review                  683 non-null    object
#  6   Aircraft                220 non-null    object
#  7   Type Of Traveller       502 non-null    object
#  8   Seat Type               628 non-null    object
#  9   Origin                  499 non-null    object
#  10  Destination             499 non-null    object
#  11  Layover                 116 non-null    object
#  12  Date Flown              501 non-null    object
#  13  Seat Comfort            632 non-null    float64
# ...

# %%
df_scoot.describe()
# Out:
#        Overall Rating  Seat Comfort  Cabin Staff Service  Food & Beverages  \
# count      662.000000    632.000000           628.000000        457.000000
# mean         4.471299      2.691456             2.901274          1.973742
# std          3.402623      1.365661             1.474871          1.353751
# min          1.000000      0.000000             0.000000          0.000000
# 25%          1.000000      1.000000             1.000000          1.000000
# 50%          3.000000      3.000000             3.000000          1.000000
# 75%          8.000000      4.000000             4.000000          3.000000
# max         10.000000      5.000000             5.000000          5.000000
#
#        Ground Service  Wifi & Connectivity  Value For Money  \
# count      475.000000           131.000000       683.000000
# mean         2.482105             1.755725         2.819912
# std          1.568814             1.265468         1.614110
# ...

# %%
df_scoot['Date Flown'].unique()
# Out:
# array(['February 2024', 'March 2024', 'January 2024', 'October 2023',
#        'December 2023', 'November 2023', 'September 2023', 'August 2023',
#        'July 2023', 'June 2023', 'May 2023', 'January 2023',
#        'February 2023', 'December 2022', 'April 2023', 'March 2023',
#        'September 2022', 'November 2022', 'July 2022', 'October 2022',
#        'May 2022', 'August 2022', 'June 2022', 'March 2022',
#        'January 2022', 'April 2022', 'February 2022', 'November 2021',
#        'October 2021', 'September 2021', 'September 2020',
#        'February 2020', 'July 2020', 'March 2020', 'May 2019',
#        'January 2020', 'December 2019', 'November 2019', 'July 2019',
#        'October 2019', 'August 2019', 'September 2019', 'June 2019',
#        'February 2019', 'March 2019', 'April 2019', 'January 2019',
#        'October 2018', 'December 2018', 'June 2018', 'November 2018',
#        'September 2018', 'July 2018', 'October 2017', 'August 2018',
# ...
