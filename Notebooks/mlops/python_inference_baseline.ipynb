# %% [markdown]
# Main resources:
# - https://brighteshun.medium.com/sentiment-analysis-part-1-finetuning-and-hosting-a-text-classification-model-on-huggingface-9d6da6fd856b

# %%
#Import Libraries
import pandas as pd
import numpy as np
from scipy.special import softmax
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report

#finetuning
from transformers import pipeline, AutoTokenizer, TrainingArguments, AutoModelForSequenceClassification, Trainer, DistilBertTokenizerFast, DefaultDataCollator

# %%
base_data = pd.read_csv("base.csv")
base_data
# Out:
#       Year                                     Cleaned_Review  \
# 0     2016  Gold Coast to Bangkok via Singapore with Scoot...
# 1     2016  My Scoot flight from Melbourne to Singapore wa...
# 2     2016  Flew back from Amritsar to Singapore on 19th S...
# 3     2016  $500 round trip from Tokyo to Taipei for a fam...
# 4     2016  Overall excellent service from Scoot, however ...
# ...    ...                                                ...
# 1594  2012  SYD-OOL. Arrived at the airport on time. Fligh...
# 1595  2012  Cairns-Sydney-Phuket in Business class. Was no...
# 1596  2012  Had the misfortune of flying Business class fr...
# 1597  2012  I have just flown from Melbourne to Sydney and...
# 1598  2012  I have flown Jetstar for a while now and to be...
#
#       is_negative_sentiment
# 0                         1
# 1                         0
# 2                         1
# 3                         1
# 4                         0
# ...                     ...
# 1594                      1
# 1595                      1
# 1596                      1
# 1597                      1
# 1598                      0
#
# [1599 rows x 3 columns]

# %%
test1_data = pd.read_csv("time_period1.csv")
test1_data
# Out:
#       Year                                     Cleaned_Review  \
# 0     2019  Our trip to Athens this month certainly met ou...
# 1     2019  Singapore to Sydney. For the most part, this a...
# 2     2019  Coimbatore to Singapore. Friendly Check-in sta...
# 3     2019  Singapore to Jakarta. There's no space to put ...
# 4     2019  Wuhan to Singapore. I am very disappointed tha...
# ...    ...                                                ...
# 1383  2017  Jetstar Airways exceeded expectations and one ...
# 1384  2017  Sydney to Melbourne with Jetstar Airways. I bo...
# 1385  2017  Adelaide to Denpasar. My first experience with...
# 1386  2017  Flew Hobart to Sydney direct yesterday. Booked...
# 1387  2017  I booked a flight Perth to Melbourne to visit ...
#
#       is_negative_sentiment
# 0                         0
# 1                         0
# 2                         1
# 3                         1
# 4                         1
# ...                     ...
# 1383                      0
# 1384                      0
# 1385                      1
# 1386                      0
# 1387                      1
#
# [1388 rows x 3 columns]

# %%
test2_data = pd.read_csv("time_period2.csv")
test2_data
# Out:
#       Year                                     Cleaned_Review  \
# 0     2024  My flight to Singapore was uneventful as usual...
# 1     2024  Using super old plane. Aircon was blowing warm...
# 2     2024  I travelled with my sister, my elderly parent ...
# 3     2024  Was assigned last two row at seat 39F with the...
# 4     2024  Very rude male flight attendant. Accessed the ...
# ...    ...                                                ...
# 1125  2020  Sydney to Launceston. For an extra two kilos i...
# 1126  2020  Denpasar to Melbourne. I had a really disappoi...
# 1127  2020  Sydney to Launceston. Yet again, Jetstar canno...
# 1128  2020  Honolulu to Sydney. I flew with Jetstar for my...
# 1129  2020  Newcastle to Mackay via Brisbane. Jetstar made...
#
#       is_negative_sentiment
# 0                         1
# 1                         1
# 2                         0
# 3                         0
# 4                         1
# ...                     ...
# 1125                      1
# 1126                      1
# 1127                      1
# 1128                      1
# 1129                      1
#
# [1130 rows x 3 columns]

# %%
sample = test2_data.iloc[5]
sample_txt, sample_label = sample['Cleaned_Review'], sample['is_negative_sentiment']
print(sample_txt)
print(sample_label)
# Out:
# Upon check-in to Phuket airport, I could see the flight had been delayed. When I advised ground staff that this would mean I would most likely miss my connecting flight in Singapore (dep 1am) through to Melbourne which would cause onward delays (including an unplanned overnight stay), and could they assist by allowing me to move to the front of the plane, or communicate with Singapore ground staff, they advised nothing could be done and that I could sort it at Singapore Changi airport. As it was, the plane was further delayed and the connecting flight was well and truly missed. As I was seated at the very back of the plane, & I could not exit from the rear, I was last off the plane, which meant I was at the back of a very long line which took 2 hours (1am - 3am Singapore time) for me to arrive at the counter in Singapore. I was told I would be on a flight at 11am to MEL. I explained that the arrival time into MEL 2130 meant that I could not get my connections across Victoria into South Australia where I live, and rather than use a hotel for the time in SIN, could I have one for late arrival into MEL. I was told there was nothing to be done and to keep all receipts and send to Scoot. As it turns out, 2 weeks after returning, 9 emails, and 4 phone calls later, Scoot said that because the flight is under 2 hours delayed, they do not cover it. This is untrue as the flight was delayed more than that. The point being that I missed my connection, leaving me arriving solo, late at night into a city I do not live in. I have flown with Singapore Airlines many times and cannot fault them. Scoot is an entirely horrible experience from start to finish and I will never recommend or fly with them again, and I will be very vocal about how poor the experience was. No communication from ground staff ever - flights out and in were all delayed and staff looked unhappy, and I would imagine are also poorly treated by also receiving no communication from above, and poor conditions. A disgrace to Singapore.
# 1

# %%
def load_model(model_path):
    tokenizer = AutoTokenizer.from_pretrained(model_path)
    model = AutoModelForSequenceClassification.from_pretrained(model_path)
    return model, tokenizer

# %%
output_dir = "baseline_pipeline_sentiments_analysis_distilbert"
model, tokenizer = load_model(output_dir)

# %%
# Process the input text and return sentiment prediction
def is_negative_sentiment_score(text):
    encoded_input = tokenizer(text, truncation=True, return_tensors="pt")  # for PyTorch-based models
    output = model(**encoded_input)
    scores_ = output[0][0].detach().numpy()
    scores_ = softmax(scores_)

    # Format output dictionary of scores
    labels = ["Negative", "Positive"]
    scores = {l: float(s) for (l, s) in zip(labels, scores_)}
    return scores.get("Negative", 0.0)

# %%
def predict(test_data_df): 
    th = 0.5

    test_data_df['negative_sentiment_score'] = test_data_df['Cleaned_Review'].apply(is_negative_sentiment_score)
    test_data_df['sentiment_acc'] = test_data_df['negative_sentiment_score'].apply(lambda score: 1 if score >= th else 0)
    return test_data_df

# %%
print(sample_txt)
print(sample_label)
is_negative_sentiment_score(sample_txt)
# Out:
# Upon check-in to Phuket airport, I could see the flight had been delayed. When I advised ground staff that this would mean I would most likely miss my connecting flight in Singapore (dep 1am) through to Melbourne which would cause onward delays (including an unplanned overnight stay), and could they assist by allowing me to move to the front of the plane, or communicate with Singapore ground staff, they advised nothing could be done and that I could sort it at Singapore Changi airport. As it was, the plane was further delayed and the connecting flight was well and truly missed. As I was seated at the very back of the plane, & I could not exit from the rear, I was last off the plane, which meant I was at the back of a very long line which took 2 hours (1am - 3am Singapore time) for me to arrive at the counter in Singapore. I was told I would be on a flight at 11am to MEL. I explained that the arrival time into MEL 2130 meant that I could not get my connections across Victoria into South Australia where I live, and rather than use a hotel for the time in SIN, could I have one for late arrival into MEL. I was told there was nothing to be done and to keep all receipts and send to Scoot. As it turns out, 2 weeks after returning, 9 emails, and 4 phone calls later, Scoot said that because the flight is under 2 hours delayed, they do not cover it. This is untrue as the flight was delayed more than that. The point being that I missed my connection, leaving me arriving solo, late at night into a city I do not live in. I have flown with Singapore Airlines many times and cannot fault them. Scoot is an entirely horrible experience from start to finish and I will never recommend or fly with them again, and I will be very vocal about how poor the experience was. No communication from ground staff ever - flights out and in were all delayed and staff looked unhappy, and I would imagine are also poorly treated by also receiving no communication from above, and poor conditions. A disgrace to Singapore.
# 1
# 0.9997226595878601

# %%
def model_inference(test_data):
    TH = 0.5

    test_data_df = predict(test_data)
    test_data_df['sentiment_acc'] = test_data_df['negative_sentiment_score'].apply(lambda score: 1 if score >= TH else 0)

    pred_labels = test_data_df['sentiment_acc']
    true_labels = test_data_df['is_negative_sentiment']

    confusion_matrix_result = confusion_matrix(pred_labels, true_labels)
    accuracy = accuracy_score(true_labels, pred_labels)

    return test_data_df, confusion_matrix_result, accuracy

# %%
output_df, confusion_matrix_result, accuracy = model_inference(base_data)

# %%
print(confusion_matrix_result)
print(accuracy)

output_df.head()
# Out:
# [[641  27]
#  [278 653]]
# 0.809255784865541
#    Year                                     Cleaned_Review  \
# 0  2016  Gold Coast to Bangkok via Singapore with Scoot...
# 1  2016  My Scoot flight from Melbourne to Singapore wa...
# 2  2016  Flew back from Amritsar to Singapore on 19th S...
# 3  2016  $500 round trip from Tokyo to Taipei for a fam...
# 4  2016  Overall excellent service from Scoot, however ...
#
#    is_negative_sentiment  negative_sentiment_score  sentiment_acc
# 0                      1                  0.996442              1
# 1                      0                  0.996511              1
# 2                      1                  0.999636              1
# 3                      1                  0.998273              1
# 4                      0                  0.330671              0

# %%
test1_output, test1_confusion_matrix_result, test1_accuracy = model_inference(test1_data)

# %%
print(test1_confusion_matrix_result)
print(test1_accuracy)

test1_output.head()
# Out:
# [[307  13]
#  [128 940]]
# 0.8984149855907781
#    Year                                     Cleaned_Review  \
# 0  2019  Our trip to Athens this month certainly met ou...
# 1  2019  Singapore to Sydney. For the most part, this a...
# 2  2019  Coimbatore to Singapore. Friendly Check-in sta...
# 3  2019  Singapore to Jakarta. There's no space to put ...
# 4  2019  Wuhan to Singapore. I am very disappointed tha...
#
#    is_negative_sentiment  negative_sentiment_score  sentiment_acc
# 0                      0                  0.001487              0
# 1                      0                  0.996364              1
# 2                      1                  0.992684              1
# 3                      1                  0.998239              1
# 4                      1                  0.999063              1

# %%
test2_output, test2_confusion_matrix_result, test2_accuracy = model_inference(test2_data)

# %%
print(test2_confusion_matrix_result)
print(test2_accuracy)

test2_output.head()
# Out:
# [[153  12]
#  [ 56 909]]
# 0.9398230088495575
#    Year                                     Cleaned_Review  \
# 0  2024  My flight to Singapore was uneventful as usual...
# 1  2024  Using super old plane. Aircon was blowing warm...
# 2  2024  I travelled with my sister, my elderly parent ...
# 3  2024  Was assigned last two row at seat 39F with the...
# 4  2024  Very rude male flight attendant. Accessed the ...
#
#    is_negative_sentiment  negative_sentiment_score  sentiment_acc
# 0                      1                  0.999516              1
# 1                      1                  0.998806              1
# 2                      0                  0.001175              0
# 3                      0                  0.008209              0
# 4                      1                  0.999674              1

# %%
# Save the DataFrame to a CSV file named 'test2_output.csv'
test2_output.to_csv('baseline_test2_output.csv', index=False)
