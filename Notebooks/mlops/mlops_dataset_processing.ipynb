# %%
import numpy as np
import pandas as pd
import csv
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
dataset_path = "all_reviews_fulldataset.csv" # use your own path
data_df = pd.read_csv(dataset_path)
data_df.head()
# Out:
#   Airline  Review ID Date Published  Overall Rating Passenger Country  \
# 0   scoot     891669      26/3/2024             3.0         Australia
# 1   scoot     891535      24/3/2024             1.0          Malaysia
# 2   scoot     891527      24/3/2024             9.0         Singapore
# 3   scoot     891411      22/3/2024             7.0     United States
# 4   scoot     891340      21/3/2024             4.0         Australia
#
#    Trip Verified                              Review Title  \
# 0   Not Verified             "not recommend flying Scoot"
# 1  Trip Verified               "whole cabin is like sauna"
# 2  Trip Verified      "professional, helpful and friendly"
# 3  Trip Verified  "seat pitch is generous and comfortable"
# 4  Trip Verified         "Very rude male flight attendant"
#
#                                               Review    Aircraft  \
# 0  My flight to Singapore was uneventful as usual...  Boeing 787
# 1  Using super old plane. Aircon was blowing warm...         NaN
# 2  I travelled with my sister, my elderly parent ...         NaN
# 3  Was assigned last two row at seat 39F with the...    A321 NEO
# 4  Very rude male flight attendant. Accessed the ...        A321
#
#   Type Of Traveller  ... Layover Date Flown Seat Comfort Cabin Staff Service  \
# 0      Solo Leisure  ...     NaN     Feb-24          1.0                 3.0
# 1      Solo Leisure  ...     NaN     Mar-24          1.0                 3.0
# 2    Family Leisure  ...     NaN     Mar-24          4.0                 5.0
# 3      Solo Leisure  ...     NaN     Mar-24          5.0                 3.0
# 4    Family Leisure  ...     NaN     Mar-24          3.0                 1.0
#
#   Food & Beverages  Ground Service  Wifi & Connectivity  Value For Money  \
# 0              1.0             3.0                  2.0              3.0
# 1              2.0             3.0                  NaN              2.0
# 2              4.0             5.0                  NaN              5.0
# 3              NaN             2.0                  2.0              5.0
# 4              NaN             4.0                  NaN              4.0
#
#    Recommended  Inflight Entertainment
# 0           no                     NaN
# 1           no                     1.0
# 2          yes                     NaN
# 3          yes                     NaN
# 4           no                     NaN
#
# [5 rows x 23 columns]

# %%
filtered_data_df = data_df[['Date Published', 'Review', 'Recommended']].copy()
filtered_data_df
# Out:
#      Date Published                                             Review  \
# 0         26/3/2024  My flight to Singapore was uneventful as usual...
# 1         24/3/2024  Using super old plane. Aircon was blowing warm...
# 2         24/3/2024  I travelled with my sister, my elderly parent ...
# 3         22/3/2024  Was assigned last two row at seat 39F with the...
# 4         21/3/2024  Very rude male flight attendant. Accessed the ...
# ...             ...                                                ...
# 4112      28/5/2012  SYD-OOL. Arrived at the airport on time. Fligh...
# 4113      25/5/2012  Cairns-Sydney-Phuket in Business class. Was no...
# 4114      21/5/2012  Had the misfortune of flying Business class fr...
# 4115      15/5/2012  I have just flown from Melbourne to Sydney and...
# 4116      14/5/2012  I have flown Jetstar for a while now and to be...
#
#      Recommended
# 0             no
# 1             no
# 2            yes
# 3            yes
# 4             no
# ...          ...
# 4112          no
# 4113          no
# 4114          no
# 4115          no
# 4116         yes
#
# [4117 rows x 3 columns]

# %%
# Extract year and month from the 'Date Published' column
filtered_data_df['Year'] = pd.to_datetime(filtered_data_df['Date Published']).dt.year

# Count occurrences by year-month
year_month_counts = filtered_data_df['Year'].value_counts()

# Sort year_month_counts by index in descending order
year_month_counts = year_month_counts.sort_index(ascending=True)

# Create a bar chart
year_month_counts.plot(kind='bar')
plt.xlabel('Year')
plt.ylabel('Count')
plt.title('Counts of Dates by Year')
plt.show()
# Out:
# C:\Users\jared\AppData\Local\Temp\ipykernel_11336\2318753317.py:2: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   filtered_data_df['Year'] = pd.to_datetime(filtered_data_df['Date Published']).dt.year

# %%
filtered_data_df.head()
# Out:
#   Date Published                                             Review  \
# 0      26/3/2024  My flight to Singapore was uneventful as usual...
# 1      24/3/2024  Using super old plane. Aircon was blowing warm...
# 2      24/3/2024  I travelled with my sister, my elderly parent ...
# 3      22/3/2024  Was assigned last two row at seat 39F with the...
# 4      21/3/2024  Very rude male flight attendant. Accessed the ...
#
#   Recommended  Year
# 0          no  2024
# 1          no  2024
# 2         yes  2024
# 3         yes  2024
# 4          no  2024

# %%
# identifying splits as follows: 2005-2016, then  2017-2019, then 2020-2024
# we check here to ensure the split is fairly even

# Define year ranges
ranges = [
    (2005, 2016),
    (2017, 2019),
    (2020, 2024)
]

# Create a dictionary to store counts
year_range_counts = {}
for year_start, year_end in ranges:
  # Filter data for the current year range
  temp_df = filtered_data_df[(filtered_data_df['Year'] >= year_start) & (filtered_data_df['Year'] <= year_end)]
  # Count occurrences
  count = len(temp_df)
  # Add count to the dictionary with range as key
  year_range_counts[f"{year_start}-{year_end}"] = count

# Calculate total count
total_count = len(filtered_data_df)

# Calculate percentages as a dictionary
percentages = {range_str: (count / total_count) * 100 for range_str, count in year_range_counts.items()}

# Create a DataFrame from the dictionary
percentages_df = pd.DataFrame.from_dict(percentages, orient='index', columns=['Percentage'])

# Reset index to convert it into a regular column
percentages_df = percentages_df.reset_index()

percentages_df.rename(columns={'index': 'Year Range'}, inplace=True)

# Print the DataFrame
percentages_df
# Out:
#   Year Range  Percentage
# 0  2005-2016   38.838960
# 1  2017-2019   33.713869
# 2  2020-2024   27.447170

# %%
# Define a list of names for the new column
column_names = ['base', 'time period 1', 'time period 2']

# Create a Series with the names as indices
new_column = pd.Series(column_names, index=percentages_df.index)

# Append the new column to the DataFrame
percentages_df = percentages_df.assign(Fragment=new_column.values)


# Print the updated DataFrame
percentages_df
# Out:
#   Year Range  Percentage       Fragment
# 0  2005-2016   38.838960           base
# 1  2017-2019   33.713869  time period 1
# 2  2020-2024   27.447170  time period 2

# %%
def clean_text(text):
    """
    Inner function for cleaning individual text entries.
    """
    replace_char=''
    return ''.join(char if char.isascii() else replace_char for char in text)

# %%
filtered_data_df['Cleaned_Review'] = filtered_data_df['Review'].apply(clean_text)

# %%
filtered_data_df.head()
# Out:
#   Date Published                                             Review  \
# 0      26/3/2024  My flight to Singapore was uneventful as usual...
# 1      24/3/2024  Using super old plane. Aircon was blowing warm...
# 2      24/3/2024  I travelled with my sister, my elderly parent ...
# 3      22/3/2024  Was assigned last two row at seat 39F with the...
# 4      21/3/2024  Very rude male flight attendant. Accessed the ...
#
#   Recommended  Year                                     Cleaned_Review
# 0          no  2024  My flight to Singapore was uneventful as usual...
# 1          no  2024  Using super old plane. Aircon was blowing warm...
# 2         yes  2024  I travelled with my sister, my elderly parent ...
# 3         yes  2024  Was assigned last two row at seat 39F with the...
# 4          no  2024  Very rude male flight attendant. Accessed the ...

# %%
distinct_values = filtered_data_df['Recommended'].unique()
distinct_values
# Out:
# array(['no', 'yes'], dtype=object)

# %%
filtered_data_df['is_negative_sentiment'] = filtered_data_df['Recommended'].map({'yes': 0, 'no': 1})
filtered_data_df
# Out:
#      Date Published                                             Review  \
# 0         26/3/2024  My flight to Singapore was uneventful as usual...
# 1         24/3/2024  Using super old plane. Aircon was blowing warm...
# 2         24/3/2024  I travelled with my sister, my elderly parent ...
# 3         22/3/2024  Was assigned last two row at seat 39F with the...
# 4         21/3/2024  Very rude male flight attendant. Accessed the ...
# ...             ...                                                ...
# 4112      28/5/2012  SYD-OOL. Arrived at the airport on time. Fligh...
# 4113      25/5/2012  Cairns-Sydney-Phuket in Business class. Was no...
# 4114      21/5/2012  Had the misfortune of flying Business class fr...
# 4115      15/5/2012  I have just flown from Melbourne to Sydney and...
# 4116      14/5/2012  I have flown Jetstar for a while now and to be...
#
#      Recommended  Year                                     Cleaned_Review  \
# 0             no  2024  My flight to Singapore was uneventful as usual...
# 1             no  2024  Using super old plane. Aircon was blowing warm...
# 2            yes  2024  I travelled with my sister, my elderly parent ...
# 3            yes  2024  Was assigned last two row at seat 39F with the...
# 4             no  2024  Very rude male flight attendant. Accessed the ...
# ...          ...   ...                                                ...
# 4112          no  2012  SYD-OOL. Arrived at the airport on time. Fligh...
# 4113          no  2012  Cairns-Sydney-Phuket in Business class. Was no...
# 4114          no  2012  Had the misfortune of flying Business class fr...
# 4115          no  2012  I have just flown from Melbourne to Sydney and...
# 4116         yes  2012  I have flown Jetstar for a while now and to be...
#
#       is_negative_sentiment
# 0                         1
# 1                         1
# 2                         0
# 3                         0
# 4                         1
# ...                     ...
# 4112                      1
# 4113                      1
# 4114                      1
# 4115                      1
# 4116                      0
#
# [4117 rows x 6 columns]

# %%
train_test_df = filtered_data_df[['Year', 'Cleaned_Review', 'is_negative_sentiment']].copy()
train_test_df
# Out:
#       Year                                     Cleaned_Review  \
# 0     2024  My flight to Singapore was uneventful as usual...
# 1     2024  Using super old plane. Aircon was blowing warm...
# 2     2024  I travelled with my sister, my elderly parent ...
# 3     2024  Was assigned last two row at seat 39F with the...
# 4     2024  Very rude male flight attendant. Accessed the ...
# ...    ...                                                ...
# 4112  2012  SYD-OOL. Arrived at the airport on time. Fligh...
# 4113  2012  Cairns-Sydney-Phuket in Business class. Was no...
# 4114  2012  Had the misfortune of flying Business class fr...
# 4115  2012  I have just flown from Melbourne to Sydney and...
# 4116  2012  I have flown Jetstar for a while now and to be...
#
#       is_negative_sentiment
# 0                         1
# 1                         1
# 2                         0
# 3                         0
# 4                         1
# ...                     ...
# 4112                      1
# 4113                      1
# 4114                      1
# 4115                      1
# 4116                      0
#
# [4117 rows x 3 columns]

# %%
# sotring data into base and time period files

# Define year ranges with descriptive names
ranges = {
    "base": (2005, 2016),  
    "time_period1": (2017, 2019),
    "time_period2": (2020, 2024)
}

# Function to filter and save data for a year range
def filter_and_save(data, year_range_name, year_start, year_end):
  filtered_df = data[(data['Year'] >= year_start) & (data['Year'] <= year_end)]
  filtered_df.to_csv(f"{year_range_name}.csv", index=False)

# Filter and save data for each range
for range_name, (year_start, year_end) in ranges.items():
  filter_and_save(train_test_df.copy(), range_name, year_start, year_end)

print("Data successfully filtered and saved to CSV files.")
# Out:
# Data successfully filtered and saved to CSV files.
